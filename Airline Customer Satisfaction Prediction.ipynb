# %% [markdown]
# # 👉🏻 Airline Customer Satisfaction Prediction

# %% [markdown]
# # 1. Importing Data By Pandas :-

# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\shahi\Downloads\ML Project - Decision Tree Airline Customer Satisfaction U16955468980.txt",header=0)

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0      id  Gender      Customer Type  Age  \
# 0             0           0   70172    Male     Loyal Customer   13
# 1             1           1    5047    Male  disloyal Customer   25
# 2             2           2  110028  Female     Loyal Customer   26
# 3             3           3   24026  Female     Loyal Customer   25
# 4             4           4  119299    Male     Loyal Customer   61
#
#     Type of Travel     Class  Flight Distance  Inflight wifi service  ...  \
# 0  Personal Travel  Eco Plus              460                      3  ...
# 1  Business travel  Business              235                      3  ...
# 2  Business travel  Business             1142                      2  ...
# 3  Business travel  Business              562                      2  ...
# 4  Business travel  Business              214                      3  ...
#
#    Inflight entertainment  On-board service  Leg room service  \
# ...

# %% [markdown]
# # 2. Data Describe with Count,mean,std,min etc..

# %%
data.describe()
# Out:
#        Unnamed: 0.1   Unnamed: 0             id           Age  \
# count   10000.00000  10000.00000   10000.000000  10000.000000
# mean     4999.50000   4999.50000   64950.978500     39.303700
# std      2886.89568   2886.89568   37420.905082     15.116478
# min         0.00000      0.00000       8.000000      7.000000
# 25%      2499.75000   2499.75000   32330.500000     27.000000
# 50%      4999.50000   4999.50000   64941.000000     40.000000
# 75%      7499.25000   7499.25000   97579.750000     51.000000
# max      9999.00000   9999.00000  129863.000000     85.000000
#
#        Flight Distance  Inflight wifi service  \
# count     10000.000000           10000.000000
# mean       1198.823800               2.731500
# std        1001.774138               1.328226
# min          31.000000               0.000000
# 25%         413.000000               2.000000
# 50%         852.500000               3.000000
# 75%        1747.000000               4.000000
# ...

# %% [markdown]
# # 3. Data Imformation With Column Names :-

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0.1                       10000 non-null  int64
#  1   Unnamed: 0                         10000 non-null  int64
#  2   id                                 10000 non-null  int64
#  3   Gender                             10000 non-null  object
#  4   Customer Type                      10000 non-null  object
#  5   Age                                10000 non-null  int64
#  6   Type of Travel                     10000 non-null  object
#  7   Class                              10000 non-null  object
#  8   Flight Distance                    10000 non-null  int64
#  9   Inflight wifi service              10000 non-null  int64
#  10  Departure/Arrival time convenient  10000 non-null  int64
# ...

# %% [markdown]
# # 4. Dropping a Column:-

# %%
data=data.drop("Unnamed: 0",axis=1)

# %%
data.head()

# %% [markdown]
# # 5. Replacing a space into underscore:-

# %%
data.columns=[each.replace(" ","_")for each in data.columns]

# %%
data.columns
# Out:
# Index(['Unnamed:_0.1', 'id', 'Gender', 'Customer_Type', 'Age',
#        'Type_of_Travel', 'Class', 'Flight_Distance', 'Inflight_wifi_service',
#        'Departure/Arrival_time_convenient', 'Ease_of_Online_booking',
#        'Gate_location', 'Food_and_drink', 'Online_boarding', 'Seat_comfort',
#        'Inflight_entertainment', 'On-board_service', 'Leg_room_service',
#        'Baggage_handling', 'Checkin_service', 'Inflight_service',
#        'Cleanliness', 'Departure_Delay_in_Minutes', 'Arrival_Delay_in_Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
data["satisfaction"].value_counts()
# Out:
# satisfaction
# neutral or dissatisfied    5689
# satisfied                  4311
# Name: count, dtype: int64

# %% [markdown]
# # 6. Creating a Charts to visualization some Columns using Matplolib:-

# %%
import matplotlib.pyplot as plt

# %%
data["satisfaction"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='satisfaction'>

# %%
data["Gender"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Gender'>

# %% [markdown]
# # 7. Cheaking Null Values in Sum:-

# %%
data.isnull().sum()
# Out:
# Unnamed:_0.1                          0
# id                                    0
# Gender                                0
# Customer_Type                         0
# Age                                   0
# Type_of_Travel                        0
# Class                                 0
# Flight_Distance                       0
# Inflight_wifi_service                 0
# Departure/Arrival_time_convenient     0
# Ease_of_Online_booking                0
# Gate_location                         0
# Food_and_drink                        0
# Online_boarding                       0
# Seat_comfort                          0
# Inflight_entertainment                0
# On-board_service                      0
# Leg_room_service                      0
# Baggage_handling                      0
# Checkin_service                       0
# Inflight_service                      0
# Cleanliness                           0
# Departure_Delay_in_Minutes            0
# ...

# %% [markdown]
# # 8. Dropping Null Values:-

# %%
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# Unnamed:_0.1                         0
# id                                   0
# Gender                               0
# Customer_Type                        0
# Age                                  0
# Type_of_Travel                       0
# Class                                0
# Flight_Distance                      0
# Inflight_wifi_service                0
# Departure/Arrival_time_convenient    0
# Ease_of_Online_booking               0
# Gate_location                        0
# Food_and_drink                       0
# Online_boarding                      0
# Seat_comfort                         0
# Inflight_entertainment               0
# On-board_service                     0
# Leg_room_service                     0
# Baggage_handling                     0
# Checkin_service                      0
# Inflight_service                     0
# Cleanliness                          0
# Departure_Delay_in_Minutes           0
# Arrival_Delay_in_Minutes             0
# ...

# %%
data["Flight_Distance"].unique()
# Out:
# array([ 460,  235, 1142, ..., 3033, 1319, 1443], dtype=int64)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9974 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed:_0.1                       9974 non-null   int64
#  1   id                                 9974 non-null   int64
#  2   Gender                             9974 non-null   object
#  3   Customer_Type                      9974 non-null   object
#  4   Age                                9974 non-null   int64
#  5   Type_of_Travel                     9974 non-null   object
#  6   Class                              9974 non-null   object
#  7   Flight_Distance                    9974 non-null   int64
#  8   Inflight_wifi_service              9974 non-null   int64
#  9   Departure/Arrival_time_convenient  9974 non-null   int64
#  10  Ease_of_Online_booking             9974 non-null   int64
# ...

# %% [markdown]
# # 9. Encoding the Data using LabelEncoder:-

# %%
from sklearn.preprocessing import LabelEncoder

# %%
enc=LabelEncoder()

# %%
data["Gender"]=enc.fit_transform(data["Gender"])
data["Customer_Type"]=enc.fit_transform(data["Customer_Type"])
data["Class"]=enc.fit_transform(data["Class"])
data["Type_of_Travel"]=enc.fit_transform(data["Type_of_Travel"])
data["satisfaction"]=enc.fit_transform(data["satisfaction"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9974 entries, 0 to 9999
# Data columns (total 25 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed:_0.1                       9974 non-null   int64
#  1   id                                 9974 non-null   int64
#  2   Gender                             9974 non-null   int32
#  3   Customer_Type                      9974 non-null   int32
#  4   Age                                9974 non-null   int64
#  5   Type_of_Travel                     9974 non-null   int32
#  6   Class                              9974 non-null   int32
#  7   Flight_Distance                    9974 non-null   int64
#  8   Inflight_wifi_service              9974 non-null   int64
#  9   Departure/Arrival_time_convenient  9974 non-null   int64
#  10  Ease_of_Online_booking             9974 non-null   int64
# ...

# %%
data=data.drop(["Unnamed:_0.1","id"],axis=1)

# %%
data
# Out:
#       Gender  Customer_Type  Age  Type_of_Travel  Class  Flight_Distance  \
# 0          1              0   13               1      2              460
# 1          1              1   25               0      0              235
# 2          0              0   26               0      0             1142
# 3          0              0   25               0      0              562
# 4          1              0   61               0      0              214
# ...      ...            ...  ...             ...    ...              ...
# 9995       1              0   50               0      0             3599
# 9996       1              0   38               0      0             3873
# 9997       0              0   39               0      0              319
# 9998       1              0   52               0      0             1363
# 9999       0              0   41               0      0             3938
#
#       Inflight_wifi_service  Departure/Arrival_time_convenient  \
# ...

# %% [markdown]
# # 10. Splitting the data into X and Y for training and testing:-

# %%
x=data.drop("satisfaction",axis=1)
y=data.satisfaction

# %%
x.shape
# Out:
# (9974, 22)

# %% [markdown]
# # 11. Scaling the Data Using StandardScaler:-

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
X_scaler=scaler.fit_transform(x)

# %% [markdown]
# # 12. Data Devided into training and testing:-

# %%
from sklearn.model_selection import train_test_split,KFold,cross_val_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=10)

# %%
x_train.shape
# Out:
# (4987, 22)

# %%
x_test.shape
# Out:
# (4987, 22)

# %% [markdown]
# # 13. Applying DicisionTreeClassifier Model in Data :-

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier(max_depth=4)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
model.score(x_train,y_train)
# Out:
# 0.9003408863043915

# %%
model.score(x_test,y_test)
# Out:
# 0.8889111690395027

# %% [markdown]
# # 13.1.. Applying RandomForestClassifier Model in Data:-

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(n_estimators=150,max_depth=2,random_state=30)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=2, n_estimators=150, random_state=30)

# %%
model.score(x_train,y_train)
# Out:
# 0.8828955283737718

# %%
model.score(x_test,y_test)
# Out:
# 0.8772809304190896

# %% [markdown]
# # 👉🏻 Apllying Multiple Models Together for the best Accuracy:-

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
lis=[LinearRegression,SVC,DecisionTreeClassifier,RandomForestClassifier,KNeighborsClassifier]

# %%
k=KFold(n_splits=4)
cross_val_score(LinearRegression(),x_train,y_train,cv=k)
# Out:
# array([0.54162627, 0.56456373, 0.52388536, 0.56291307])

# %%
for i in lis:
    model=i()
    k=KFold(n_splits=4)
    print(i)
    print(cross_val_score(model,x_train,y_train,cv=k).mean())
# Out:
# <class 'sklearn.linear_model._base.LinearRegression'>
# 0.5482471075037937
# <class 'sklearn.svm._classes.SVC'>
# 0.6627182927629843
# <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# 0.9097680339717409
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>
# 0.9346312369590709
# <class 'sklearn.neighbors._classification.KNeighborsClassifier'>
# 0.6384587858372132

# %%
model=RandomForestClassifier(n_estimators=250,random_state=20,max_depth=9)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=9, n_estimators=250, random_state=20)

# %%
model.score(x_train,y_train)
# Out:
# 0.9614998997393223

# %%
model.score(x_test,y_test)
# Out:
# 0.935432123521155

# %%
dic={"n_estimators":[150,200,250],
    "random_state":[10,20,30],
    "max_depth":[7,8,9]}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random=RandomizedSearchCV(RandomForestClassifier(),param_distributions=dic,cv=k,verbose=2,n_iter=10)

# %%
random.fit(x_train,y_train)
# Out:
# Fitting 4 folds for each of 10 candidates, totalling 40 fits
# [CV] END .....max_depth=8, n_estimators=250, random_state=20; total time=   0.6s
# [CV] END .....max_depth=8, n_estimators=250, random_state=20; total time=   0.6s
# [CV] END .....max_depth=8, n_estimators=250, random_state=20; total time=   0.6s
# [CV] END .....max_depth=8, n_estimators=250, random_state=20; total time=   0.6s
# [CV] END .....max_depth=9, n_estimators=200, random_state=20; total time=   0.5s
# [CV] END .....max_depth=9, n_estimators=200, random_state=20; total time=   0.5s
# [CV] END .....max_depth=9, n_estimators=200, random_state=20; total time=   0.6s
# [CV] END .....max_depth=9, n_estimators=200, random_state=20; total time=   0.5s
# [CV] END .....max_depth=9, n_estimators=150, random_state=10; total time=   0.4s
# [CV] END .....max_depth=9, n_estimators=150, random_state=10; total time=   0.3s
# [CV] END .....max_depth=9, n_estimators=150, random_state=10; total time=   0.4s
# ...

# %%
random.best_params_
# Out:
# {'random_state': 10, 'n_estimators': 150, 'max_depth': 9}

# %%
model=random.best_estimator_

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=9, n_estimators=150, random_state=10)

# %%
model.score(x_train,y_train)
# Out:
# 0.9612993783837979

# %%
model.score(x_test,y_test)
# Out:
# 0.9360336875877281

# %%
### After applying all the models i got a best accuracy using RandomForestClassifi

# %%
import joblib

# %%
pwd
# Out:
# 'C:\\Users\\shahi'

# %%
cd "Machine Learning/"
# Out:
# [WinError 2] The system cannot find the file specified: 'Machine Learning/'
# C:\Users\shahi

# %%
joblib.dump(model,"ml_model.pkl")
# Out:
# ['ml_model.pkl']
